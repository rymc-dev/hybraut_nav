# %% [markdown]
# # Finite State Controller Analysis
#
# This is a finite state controller analysis for turtlebot3 gazebo simulation to quantitatately and qualitatavly analyse this finite state controller works as expected
